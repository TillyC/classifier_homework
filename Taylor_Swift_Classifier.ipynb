# %%
# import pandas and rename as pd
import pandas as pd
#import stopwords
import nltk
from nltk.corpus import stopwords
#from stop_words import get_stop_words

# %%
#set the file path
path = 'evermore_lyrics.csv'

# %%
# convert our csv file to a pandas DataFrame
swift_lyrics = pd.read_csv(path)

# %%
#print the DataFrame
swift_lyrics
# Out:
#                     album_name       track_title  track_n  \
# 0    evermore (deluxe version)            willow        1
# 1    evermore (deluxe version)            willow        1
# 2    evermore (deluxe version)            willow        1
# 3    evermore (deluxe version)            willow        1
# 4    evermore (deluxe version)            willow        1
# ..                         ...               ...      ...
# 907  evermore (deluxe version)  ​it’s time to go       17
# 908  evermore (deluxe version)  ​it’s time to go       17
# 909  evermore (deluxe version)  ​it’s time to go       17
# 910  evermore (deluxe version)  ​it’s time to go       17
# 911  evermore (deluxe version)  ​it’s time to go       17
#
#                                                  lyric  line
# 0    I'm like the water when your ship rolled in th...     1
# 1    Rough on the surface, but you cut through like...     2
# 2                      And if it was an open-shut case     3
# 3    I never would've known from that look on your ...     4
# 4           Lost in your current like a priceless wine     5
# ..                                                 ...   ...
# 907             You know, you know, you know, you know    50
# 908                               When it's time to go    51
# 909                                     So then you go    52
# 910                                        Then you go    53
# 911                                        You just go    54
#
# [912 rows x 5 columns]

# %%
#print all the different track titles 
swift_lyrics.track_title.unique()
# Out:
# array(['willow', 'champagne problems', '\u200bgold rush',
#        '\u200b’tis the damn season', '\u200btolerate it',
#        '\u200bno body, no crime', '\u200bhappiness', '\u200bdorothea',
#        '\u200bconey island', '\u200bivy', 'cowboy like me',
#        '\u200bl\u200bong story short', '\u200bmarjorie', '\u200bclosure',
#        '\u200bevermore', '\u200br\u200bight where you left me',
#        '\u200bit’s time to go'], dtype=object)

# %%
lyrics = swift_lyrics.lyric

# %%
lyrics
# Out:
# 0      I'm like the water when your ship rolled in th...
# 1      Rough on the surface, but you cut through like...
# 2                        And if it was an open-shut case
# 3      I never would've known from that look on your ...
# 4             Lost in your current like a priceless wine
#                              ...
# 907               You know, you know, you know, you know
# 908                                 When it's time to go
# 909                                       So then you go
# 910                                          Then you go
# 911                                          You just go
# Name: lyric, Length: 912, dtype: object

# %%
from stop_words import get_stop_words

# here's the template for how we want to structure our features
# {'first_keyword': slkdjfsl, 'second_keyword': lsdjfls, 'third_keyword': slkdjf}
def create_features(lyrics):
    # make all the words lowercase
    song_lyrics = lyrics.lower()
    # split the headline into a list of words
    words = song_lyrics.split()
    # using list comprehension to create a list of keywords
    keywords = [ x for x in words if x not in get_stop_words('english')  ]
    # make sure all keyword lists have three elements
    while len(keywords) < 3:
        keywords.append('None')
    return {'first_keyword': keywords[0], 'second_keyword': keywords[1], 'third_keyword': keywords[2]}

# %%
# bring together the track(label), and the lyrics(features)
zipped_feature_and_labels = zip(lyrics, swift_lyrics.track_title)

# %%
#check that the function works
create_features('It was sighted off of Rt 19')
# Out:
# {'first_keyword': 'sighted', 'second_keyword': 'rt', 'third_keyword': '19'}

# %%
# we are creating a list of tuples
# we want () around our headline and category to show they are tuples
feature_sets = [ (create_features(x),y) for x,y in zipped_feature_and_labels   ]
feature_sets
# Out:
# [({'first_keyword': 'like',
#    'second_keyword': 'water',
#    'third_keyword': 'ship'},
#   'willow'),
#  ({'first_keyword': 'rough',
#    'second_keyword': 'surface,',
#    'third_keyword': 'cut'},
#   'willow'),
#  ({'first_keyword': 'open-shut',
#    'second_keyword': 'case',
#    'third_keyword': 'None'},
#   'willow'),
#  ({'first_keyword': 'never',
#    'second_keyword': "would've",
#    'third_keyword': 'known'},
#   'willow'),
#  ({'first_keyword': 'lost',
#    'second_keyword': 'current',
#    'third_keyword': 'like'},
#   'willow'),
#  ({'first_keyword': 'say,', 'second_keyword': 'less', 'third_keyword': 'know'},
#   'willow'),
#  ({'first_keyword': 'wherever',
#    'second_keyword': 'stray,',
#    'third_keyword': 'follow'},
#   'willow'),
#  ({'first_keyword': 'begging',
#    'second_keyword': 'take',
#    'third_keyword': 'hand'},
#   'willow'),
#  ({'first_keyword': 'wreck',
#    'second_keyword': 'plans,',
#    'third_keyword': 'man'},
#   'willow'),
#  ({'first_keyword': 'life',
#    'second_keyword': 'willow',
#    'third_keyword': 'bent'},
#   'willow'),
#  ({'first_keyword': 'head',
#    'second_keyword': 'pillow,',
#    'third_keyword': 'feel'},
#   'willow'),
#  ({'first_keyword': 'mythical',
#    'second_keyword': 'thing',
#    'third_keyword': 'None'},
#   'willow'),
#  ({'first_keyword': 'like',
#    'second_keyword': 'trophy',
#    'third_keyword': 'champion'},
#   'willow'),
#  ({'first_keyword': 'one',
#    'second_keyword': 'prize',
#    'third_keyword': 'cheat'},
#   'willow'),
#  ({'first_keyword': 'say,', 'second_keyword': 'less', 'third_keyword': 'know'},
#   'willow'),
#  ({'first_keyword': 'wherever',
#    'second_keyword': 'stray,',
#    'third_keyword': 'follow'},
#   'willow'),
#  ({'first_keyword': 'begging',
#    'second_keyword': 'take',
#    'third_keyword': 'hand'},
#   'willow'),
#  ({'first_keyword': 'wreck',
#    'second_keyword': 'plans,',
#    'third_keyword': 'man'},
#   'willow'),
#  ({'first_keyword': 'know',
#    'second_keyword': 'train',
#    'third_keyword': 'take'},
#   'willow'),
#  ({'first_keyword': 'anywhere',
#    'second_keyword': 'else',
#    'third_keyword': 'hollow'},
#   'willow'),
#  ({'first_keyword': 'begging',
#    'second_keyword': 'take',
#    'third_keyword': 'hand'},
#   'willow'),
#  ({'first_keyword': 'wreck',
#    'second_keyword': 'plans,',
#    'third_keyword': 'man'},
#   'willow'),
#  ({'first_keyword': 'life',
#    'second_keyword': 'willow',
#    'third_keyword': 'bent'},
#   'willow'),
#  ({'first_keyword': 'count',
#    'second_keyword': 'time',
#    'third_keyword': 'time'},
#   'willow'),
#  ({'first_keyword': 'life',
#    'second_keyword': 'willow',
#    'third_keyword': 'bent'},
#   'willow'),
#  ({'first_keyword': 'come',
#    'second_keyword': 'back',
#    'third_keyword': 'stronger'},
#   'willow'),
#  ({'first_keyword': 'wait',
#    'second_keyword': 'signal,',
#    'third_keyword': 'meet'},
#   'willow'),
#  ({'first_keyword': 'show',
#    'second_keyword': 'places',
#    'third_keyword': 'others'},
#   'willow'),
#  ({'first_keyword': 'now',
#    'second_keyword': 'open-shut',
#    'third_keyword': 'case'},
#   'willow'),
#  ({'first_keyword': 'guess',
#    'second_keyword': "should've",
#    'third_keyword': 'known'},
#   'willow'),
#  ({'first_keyword': 'every',
#    'second_keyword': 'bait-and-switch',
#    'third_keyword': 'work'},
#   'willow'),
#  ({'first_keyword': 'say,', 'second_keyword': 'less', 'third_keyword': 'know'},
#   'willow'),
#  ({'first_keyword': 'wherever',
#    'second_keyword': 'stray,',
#    'third_keyword': 'follow'},
#   'willow'),
#  ({'first_keyword': 'begging',
#    'second_keyword': 'take',
#    'third_keyword': 'hand'},
#   'willow'),
#  ({'first_keyword': 'wreck',
#    'second_keyword': 'plans,',
#    'third_keyword': 'man'},
#   'willow'),
#  ({'first_keyword': 'know',
#    'second_keyword': 'train',
#    'third_keyword': 'take'},
#   'willow'),
#  ({'first_keyword': 'anywhere',
#    'second_keyword': 'else',
#    'third_keyword': 'hollow'},
#   'willow'),
#  ({'first_keyword': 'begging',
#    'second_keyword': 'take',
#    'third_keyword': 'hand'},
#   'willow'),
#  ({'first_keyword': 'wreck',
#    'second_keyword': 'plans,',
#    'third_keyword': 'man'},
#   'willow'),
#  ({'first_keyword': 'say,', 'second_keyword': 'less', 'third_keyword': 'know'},
#   'willow'),
#  ({'first_keyword': 'wherever',
#    'second_keyword': 'stray,',
#    'third_keyword': 'follow'},
#   'willow'),
#  ({'first_keyword': 'begging',
#    'second_keyword': 'take',
#    'third_keyword': 'hand'},
#   'willow'),
#  ({'first_keyword': 'wreck',
#    'second_keyword': 'plans,',
#    'third_keyword': 'man'},
#   'willow'),
#  ({'first_keyword': 'know',
#    'second_keyword': 'train',
#    'third_keyword': 'take'},
#   'willow'),
#  ({'first_keyword': 'anywhere',
#    'second_keyword': 'else',
#    'third_keyword': 'hollow'},
#   'willow'),
#  ({'first_keyword': 'begging',
#    'second_keyword': 'take',
#    'third_keyword': 'hand'},
#   'willow'),
#  ({'first_keyword': 'wreck',
#    'second_keyword': 'plans,',
#    'third_keyword': 'man'},
#   'willow'),
#  ({'first_keyword': 'hey,', 'second_keyword': 'man', 'third_keyword': 'None'},
#   'willow'),
#  ({'first_keyword': 'man', 'second_keyword': 'None', 'third_keyword': 'None'},
#   'willow'),
#  ({'first_keyword': 'yeah,', 'second_keyword': 'man', 'third_keyword': 'None'},
#   'willow'),
#  ({'first_keyword': 'every',
#    'second_keyword': 'bait-and-switch',
#    'third_keyword': 'work'},
#   'willow'),
#  ({'first_keyword': 'man', 'second_keyword': 'None', 'third_keyword': 'None'},
#   'willow'),
#  ({'first_keyword': 'hey,', 'second_keyword': 'man', 'third_keyword': 'None'},
#   'willow'),
#  ({'first_keyword': 'begging',
#    'second_keyword': 'take',
#    'third_keyword': 'hand'},
#   'willow'),
#  ({'first_keyword': 'wreck',
#    'second_keyword': 'plans,',
#    'third_keyword': 'man'},
#   'willow'),
#  ({'first_keyword': 'booked',
#    'second_keyword': 'night',
#    'third_keyword': 'train'},
#   'champagne problems'),
#  ({'first_keyword': 'sit', 'second_keyword': 'hurt', 'third_keyword': 'None'},
#   'champagne problems'),
#  ({'first_keyword': 'bustling',
#    'second_keyword': 'crowds',
#    'third_keyword': 'silent'},
#   'champagne problems'),
#  ({'first_keyword': 'sure',
#    'second_keyword': 'worse',
#    'third_keyword': 'None'},
#   'champagne problems'),
#  ({'first_keyword': 'dropped',
#    'second_keyword': 'hand',
#    'third_keyword': 'dancing'},
#   'champagne problems'),
#  ({'first_keyword': 'left',
#    'second_keyword': 'standing',
#    'third_keyword': 'None'},
#   'champagne problems'),
#  ({'first_keyword': 'crestfallen',
#    'second_keyword': 'landing',
#    'third_keyword': 'None'},
#   'champagne problems'),
#  ({'first_keyword': 'champagne',
#    'second_keyword': 'problems',
#    'third_keyword': 'None'},
#   'champagne problems'),
#  ({'first_keyword': "mom's",
#    'second_keyword': 'ring',
#    'third_keyword': 'pocket'},
#   'champagne problems'),
#  ({'first_keyword': 'picture',
#    'second_keyword': 'wallet',
#    'third_keyword': 'None'},
#   'champagne problems'),
#  ({'first_keyword': 'heart',
#    'second_keyword': 'glass,',
#    'third_keyword': 'dropped'},
#   'champagne problems'),
#  ({'first_keyword': 'champagne',
#    'second_keyword': 'problems',
#    'third_keyword': 'None'},
#   'champagne problems'),
#  ({'first_keyword': 'told',
#    'second_keyword': 'family',
#    'third_keyword': 'reason'},
#   'champagne problems'),
#  ({'first_keyword': 'keep', 'second_keyword': 'None', 'third_keyword': 'None'},
#   'champagne problems'),
#  ({'first_keyword': 'sister',
#    'second_keyword': 'splashed',
#    'third_keyword': 'bottle'},
#   'champagne problems'),
#  ({'first_keyword': 'now',
#    'second_keyword': "one's",
#    'third_keyword': 'celebrating'},
#   'champagne problems'),
#  ({'first_keyword': 'dom',
#    'second_keyword': 'pérignon,',
#    'third_keyword': 'brought'},
#   'champagne problems'),
#  ({'first_keyword': 'crowd',
#    'second_keyword': 'friends',
#    'third_keyword': 'applauded'},
#   'champagne problems'),
#  ({'first_keyword': 'hometown',
#    'second_keyword': 'skeptics',
#    'third_keyword': 'called'},
#   'champagne problems'),
#  ({'first_keyword': 'champagne',
#    'second_keyword': 'problems',
#    'third_keyword': 'None'},
#   'champagne problems'),
#  ({'first_keyword': 'speech,',
#    'second_keyword': 'speechless',
#    'third_keyword': 'None'},
#   'champagne problems'),
#  ({'first_keyword': 'love',
#    'second_keyword': 'slipped',
#    'third_keyword': 'beyond'},
#   'champagne problems'),
#  ({'first_keyword': 'give',
#    'second_keyword': 'reason',
#    'third_keyword': 'None'},
#   'champagne problems'),
#  ({'first_keyword': 'champagne',
#    'second_keyword': 'problems',
#    'third_keyword': 'None'},
#   'champagne problems'),
#  ({'first_keyword': 'joeboy',
#    'second_keyword': "'sip",
#    'third_keyword': "(alcohol)'"},
#   'champagne problems'),
#  ({'first_keyword': 'midas',
#    'second_keyword': 'touch',
#    'third_keyword': 'chevy'},
#   'champagne problems'),
#  ({'first_keyword': 'november',
#    'second_keyword': 'flush',
#    'third_keyword': 'flannel'},
#   'champagne problems'),
#  ({'first_keyword': '"this',
#    'second_keyword': 'dorm',
#    'third_keyword': 'madhouse"'},
#   'champagne problems'),
#  ({'first_keyword': 'made',
#    'second_keyword': 'joke,',
#    'third_keyword': '"well,'},
#   'champagne problems'),
#  ({'first_keyword': 'evergreen,',
#    'second_keyword': 'group',
#    'third_keyword': 'friends'},
#   'champagne problems'),
#  ({'first_keyword': 'think', 'second_keyword': 'say', 'third_keyword': 'word'},
#   'champagne problems'),
#  ({'first_keyword': 'soon',
#    'second_keyword': 'nerve',
#    'third_keyword': 'deck'},
#   'champagne problems'),
#  ({'first_keyword': 'walked',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   'champagne problems'),
#  ({'first_keyword': 'one', 'second_keyword': 'money,', 'third_keyword': 'two'},
#   'champagne problems'),
#  ({'first_keyword': 'never',
#    'second_keyword': 'ready',
#    'third_keyword': 'watch'},
#   'champagne problems'),
#  ({'first_keyword': 'sometimes',
#    'second_keyword': 'just',
#    'third_keyword': 'know'},
#   'champagne problems'),
#  ({'first_keyword': "'til",
#    'second_keyword': "someone's",
#    'third_keyword': 'knees'},
#   'champagne problems'),
#  ({'first_keyword': '"she',
#    'second_keyword': "would've",
#    'third_keyword': 'made'},
#   'champagne problems'),
#  ({'first_keyword': 'shame',
#    'second_keyword': 'fucked',
#    'third_keyword': 'head,"'},
#   'champagne problems'),
#  ({'first_keyword': 'find',
#    'second_keyword': 'real',
#    'third_keyword': 'thing'},
#   'champagne problems'),
#  ({'first_keyword': 'patch',
#    'second_keyword': 'tapestry',
#    'third_keyword': 'shred'},
#   'champagne problems'),
#  ({'first_keyword': 'hold',
#    'second_keyword': 'hand',
#    'third_keyword': 'dancing'},
#   'champagne problems'),
#  ({'first_keyword': 'never',
#    'second_keyword': 'leave',
#    'third_keyword': 'standing'},
#   'champagne problems'),
#  ({'first_keyword': 'crestfallen',
#    'second_keyword': 'landing',
#    'third_keyword': 'None'},
#   'champagne problems'),
#  ({'first_keyword': 'champagne',
#    'second_keyword': 'problems',
#    'third_keyword': 'None'},
#   'champagne problems'),
#  ({'first_keyword': "mom's",
#    'second_keyword': 'ring',
#    'third_keyword': 'pocket'},
#   'champagne problems'),
#  ({'first_keyword': 'picture',
#    'second_keyword': 'wallet',
#    'third_keyword': 'None'},
#   'champagne problems'),
#  ({'first_keyword': 'remember',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   'champagne problems'),
#  ({'first_keyword': 'champagne',
#    'second_keyword': 'problems',
#    'third_keyword': 'None'},
#   'champagne problems'),
#  ({'first_keyword': 'remember',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   'champagne problems'),
#  ({'first_keyword': 'champagne',
#    'second_keyword': 'problems',
#    'third_keyword': 'None'},
#   'champagne problems'),
#  ({'first_keyword': 'gleaming,',
#    'second_keyword': 'twinkling',
#    'third_keyword': 'None'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'eyes',
#    'second_keyword': 'like',
#    'third_keyword': 'sinking'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'inviting,',
#    'second_keyword': 'almost',
#    'third_keyword': 'jump'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'like',
#    'second_keyword': 'gold',
#    'third_keyword': 'rush,'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'like',
#    'second_keyword': "anticipatin'",
#    'third_keyword': 'face'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'like',
#    'second_keyword': 'anyone',
#    'third_keyword': 'die'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'everybody',
#    'second_keyword': 'wants',
#    'third_keyword': 'None'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'everybody',
#    'second_keyword': 'wonders',
#    'third_keyword': 'like'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'walk',
#    'second_keyword': 'past,',
#    'third_keyword': 'quick'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'like',
#    'second_keyword': 'slow',
#    'third_keyword': 'motion,'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'like',
#    'second_keyword': 'falling',
#    'third_keyword': 'feels'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'everybody',
#    'second_keyword': 'wants',
#    'third_keyword': 'None'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'like', 'second_keyword': 'gold', 'third_keyword': 'rush'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'must', 'second_keyword': 'like', 'third_keyword': 'grow'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'hair',
#    'second_keyword': 'falling',
#    'third_keyword': 'place'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'see',
#    'second_keyword': 'padding',
#    'third_keyword': 'across'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'eagles',
#    'second_keyword': 't-shirt',
#    'third_keyword': 'hanging'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'dinner',
#    'second_keyword': 'parties,',
#    'third_keyword': 'call'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'coastal',
#    'second_keyword': 'town',
#    'third_keyword': 'wandered'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'thеn',
#    'second_keyword': 'fades',
#    'third_keyword': 'gray'},
#   '\u200bgold rush'),
#  ({'first_keyword': "'cause",
#    'second_keyword': 'never',
#    'third_keyword': 'None'},
#   '\u200bgold rush'),
#  ({'first_keyword': "'cause",
#    'second_keyword': 'like',
#    'third_keyword': 'gold'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'like',
#    'second_keyword': "anticipatin'",
#    'third_keyword': 'face'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'like',
#    'second_keyword': 'anyone',
#    'third_keyword': 'die'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'everybody',
#    'second_keyword': 'wants',
#    'third_keyword': 'None'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'everybody',
#    'second_keyword': 'wonders',
#    'third_keyword': 'like'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'walk',
#    'second_keyword': 'past,',
#    'third_keyword': 'quick'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'like',
#    'second_keyword': 'slow',
#    'third_keyword': 'motion,'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'like',
#    'second_keyword': 'falling',
#    'third_keyword': 'feels'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'everybody',
#    'second_keyword': 'wants',
#    'third_keyword': 'None'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'like', 'second_keyword': 'gold', 'third_keyword': 'rush'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'must', 'second_keyword': 'like', 'third_keyword': 'grow'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'hair',
#    'second_keyword': 'falling',
#    'third_keyword': 'place'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'mind',
#    'second_keyword': 'turns',
#    'third_keyword': 'life'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'dare',
#    'second_keyword': 'dream',
#    'third_keyword': 'anymore'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'dinner',
#    'second_keyword': 'parties',
#    'third_keyword': 'call'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'coastal',
#    'second_keyword': 'town',
#    'third_keyword': 'never'},
#   '\u200bgold rush'),
#  ({'first_keyword': "'cause",
#    'second_keyword': 'fades',
#    'third_keyword': 'gray'},
#   '\u200bgold rush'),
#  ({'first_keyword': "'cause",
#    'second_keyword': 'will',
#    'third_keyword': 'never'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'gleaming,',
#    'second_keyword': 'twinkling',
#    'third_keyword': 'None'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'eyes',
#    'second_keyword': 'like',
#    'third_keyword': 'sinking'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'inviting,',
#    'second_keyword': 'almost',
#    'third_keyword': 'jump'},
#   '\u200bgold rush'),
#  ({'first_keyword': 'wanted',
#    'second_keyword': 'know',
#    'third_keyword': 'hanging'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'gone,',
#    'second_keyword': "would've",
#    'third_keyword': 'asked'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'kind',
#    'second_keyword': 'cold,',
#    'third_keyword': 'fogs'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'felt',
#    'second_keyword': 'passed',
#    'third_keyword': 'None'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'ache', 'second_keyword': 'you,', 'third_keyword': 'put'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'None', 'second_keyword': 'None', 'third_keyword': 'None'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'None', 'second_keyword': 'None', 'third_keyword': 'None'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'call', 'second_keyword': 'even', 'third_keyword': 'None'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'call',
#    'second_keyword': '"babe"',
#    'third_keyword': 'weekend'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': "\u200b'tis",
#    'second_keyword': 'damn',
#    'third_keyword': 'season,'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': "stayin'",
#    'second_keyword': "parents'",
#    'third_keyword': 'house'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'road',
#    'second_keyword': 'taken',
#    'third_keyword': 'looks'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'always',
#    'second_keyword': 'leads',
#    'third_keyword': 'hometown'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'parkеd',
#    'second_keyword': 'car',
#    'third_keyword': 'right'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'thе',
#    'second_keyword': 'school',
#    'third_keyword': 'used'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'holidays',
#    'second_keyword': 'linger',
#    'third_keyword': 'like'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'can', 'second_keyword': 'run,', 'third_keyword': 'far'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'escaped',
#    'second_keyword': 'too,',
#    'third_keyword': 'remember'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'okay', 'second_keyword': 'you,', 'third_keyword': 'okay'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'call', 'second_keyword': 'even', 'third_keyword': 'None'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'call',
#    'second_keyword': '"babe"',
#    'third_keyword': 'weekend'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': "\u200b'tis",
#    'second_keyword': 'damn',
#    'third_keyword': 'season,'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': "stayin'",
#    'second_keyword': "parents'",
#    'third_keyword': 'house'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'road',
#    'second_keyword': 'taken',
#    'third_keyword': 'looks'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'time',
#    'second_keyword': 'flies,',
#    'third_keyword': 'messy'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'now',
#    'second_keyword': 'missing',
#    'third_keyword': 'smile,'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'just',
#    'second_keyword': 'ride',
#    'third_keyword': 'around'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'road',
#    'second_keyword': 'taken',
#    'third_keyword': 'looks'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'always',
#    'second_keyword': 'leads',
#    'third_keyword': 'hometown'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'sleep', 'second_keyword': 'half', 'third_keyword': 'day'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'ask', 'second_keyword': 'wait', 'third_keyword': 'ask'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'go', 'second_keyword': 'back', 'third_keyword': 'l.a.'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': "who'll",
#    'second_keyword': 'write',
#    'third_keyword': 'books'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'wonder',
#    'second_keyword': 'soul',
#    'third_keyword': 'None'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'can',
#    'second_keyword': 'tell',
#    'third_keyword': 'smiles'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'heart',
#    'second_keyword': 'know',
#    'third_keyword': "breakin'"},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'leave',
#    'second_keyword': 'warmest',
#    'third_keyword': 'bed'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'call', 'second_keyword': 'even', 'third_keyword': 'None'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'even',
#    'second_keyword': 'though',
#    'third_keyword': 'leaving'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'weekend',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': "\u200b'tis",
#    'second_keyword': 'damn',
#    'third_keyword': 'season'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'call', 'second_keyword': 'even', 'third_keyword': 'None'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'call',
#    'second_keyword': '"babe"',
#    'third_keyword': 'weekend'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': "\u200b'tis",
#    'second_keyword': 'damn',
#    'third_keyword': 'season,'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': "stayin'",
#    'second_keyword': "parents'",
#    'third_keyword': 'house'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'road',
#    'second_keyword': 'taken',
#    'third_keyword': 'looks'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'time',
#    'second_keyword': 'flies,',
#    'third_keyword': 'messy'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'now',
#    'second_keyword': 'missing',
#    'third_keyword': 'smile,'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'just',
#    'second_keyword': 'ride',
#    'third_keyword': 'around'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'road',
#    'second_keyword': 'taken',
#    'third_keyword': 'looks'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'always',
#    'second_keyword': 'leads',
#    'third_keyword': 'hometown'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'always',
#    'second_keyword': 'leads',
#    'third_keyword': 'hometown'},
#   '\u200b’tis the damn season'),
#  ({'first_keyword': 'sit',
#    'second_keyword': 'watch',
#    'third_keyword': 'reading'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'wake',
#    'second_keyword': 'watch',
#    'third_keyword': 'breathing'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'sit', 'second_keyword': 'watch', 'third_keyword': 'None'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'notice',
#    'second_keyword': 'everything',
#    'third_keyword': 'None'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'much',
#    'second_keyword': 'older',
#    'third_keyword': 'wiser,'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'wait', 'second_keyword': 'door', 'third_keyword': 'like'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'use',
#    'second_keyword': 'best',
#    'third_keyword': 'colors'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'lay',
#    'second_keyword': 'table',
#    'third_keyword': 'fancy'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'watch',
#    'second_keyword': 'tolerate',
#    'third_keyword': 'None'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'head,', 'second_keyword': 'tell', 'third_keyword': 'now'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'tell', 'second_keyword': 'got', 'third_keyword': 'wrong'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'know',
#    'second_keyword': 'love',
#    'third_keyword': 'celebrated'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'tolerate',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'greet',
#    'second_keyword': 'battle',
#    'third_keyword': "hero's"},
#   '\u200btolerate it'),
#  ({'first_keyword': 'take',
#    'second_keyword': 'indiscretions',
#    'third_keyword': 'good'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'sit',
#    'second_keyword': 'listеn,',
#    'third_keyword': 'polish'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'much',
#    'second_keyword': 'older',
#    'third_keyword': 'wiser'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'wait', 'second_keyword': 'door', 'third_keyword': 'like'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'use',
#    'second_keyword': 'best',
#    'third_keyword': 'colors'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'lay',
#    'second_keyword': 'table',
#    'third_keyword': 'fancy'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'watch',
#    'second_keyword': 'tolerate',
#    'third_keyword': 'None'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'head,', 'second_keyword': 'tell', 'third_keyword': 'now'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'tell', 'second_keyword': 'got', 'third_keyword': 'wrong'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'know',
#    'second_keyword': 'love',
#    'third_keyword': 'celebrated'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'tolerate',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'building',
#    'second_keyword': 'worlds,',
#    'third_keyword': 'i?'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'man',
#    'second_keyword': "who'd",
#    'third_keyword': 'throw'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'made',
#    'second_keyword': 'temple,',
#    'third_keyword': 'mural,'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'now',
#    'second_keyword': 'begging',
#    'third_keyword': 'footnotes'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'drawing',
#    'second_keyword': 'hearts',
#    'third_keyword': 'byline'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'always',
#    'second_keyword': 'taking',
#    'third_keyword': 'much'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'assume',
#    'second_keyword': 'fine,',
#    'third_keyword': 'None'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'break',
#    'second_keyword': 'free',
#    'third_keyword': 'leave'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'took',
#    'second_keyword': 'dagger',
#    'third_keyword': 'removed'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'gain',
#    'second_keyword': 'weight',
#    'third_keyword': 'you,'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'believe',
#    'second_keyword': 'me,',
#    'third_keyword': 'None'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'head,', 'second_keyword': 'tell', 'third_keyword': 'now'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'tell', 'second_keyword': 'got', 'third_keyword': 'wrong'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'know',
#    'second_keyword': 'love',
#    'third_keyword': 'celebrated'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'tolerate',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'sit', 'second_keyword': 'watch', 'third_keyword': 'None'},
#   '\u200btolerate it'),
#  ({'first_keyword': 'None', 'second_keyword': 'None', 'third_keyword': 'None'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'None', 'second_keyword': 'None', 'third_keyword': 'None'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': "este's",
#    'second_keyword': 'friend',
#    'third_keyword': 'mine'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'meet',
#    'second_keyword': 'every',
#    'third_keyword': 'tuesday'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': "este's",
#    'second_keyword': "losin'",
#    'third_keyword': 'sleep'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': "husband's",
#    'second_keyword': "actin'",
#    'third_keyword': 'different,'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'says,',
#    'second_keyword': '"that',
#    'third_keyword': "ain't"},
#   '\u200bno body, no crime'),
#  ({'first_keyword': "ain't",
#    'second_keyword': 'jewelry',
#    'third_keyword': 'joint'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'no,',
#    'second_keyword': "ain't",
#    'third_keyword': 'doubt'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'think',
#    'second_keyword': 'gonna',
#    'third_keyword': 'call'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'says,', 'second_keyword': '"i', 'third_keyword': 'think'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'think', 'second_keyword': 'it,', 'third_keyword': 'just'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'think', 'second_keyword': 'it,', 'third_keyword': 'just'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'no,',
#    'second_keyword': 'body,',
#    'third_keyword': 'crime'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': "ain't",
#    'second_keyword': "lettin'",
#    'third_keyword': 'day'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'no,', 'second_keyword': 'None', 'third_keyword': 'None'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'think',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'no,', 'second_keyword': 'None', 'third_keyword': 'None'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'None', 'second_keyword': 'None', 'third_keyword': 'None'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'este',
#    'second_keyword': 'tuesday',
#    'third_keyword': 'night'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'job',
#    'second_keyword': 'anywhere',
#    'third_keyword': 'None'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'hе',
#    'second_keyword': 'reports',
#    'third_keyword': 'missing'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'noticed',
#    'second_keyword': 'passed',
#    'third_keyword': 'house'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'truck',
#    'second_keyword': 'got',
#    'third_keyword': 'brand'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'mistress',
#    'second_keyword': 'moved',
#    'third_keyword': 'None'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'sleeps',
#    'second_keyword': "este's",
#    'third_keyword': 'bed'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'no,',
#    'second_keyword': "ain't",
#    'third_keyword': 'doubt'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': "somebody's",
#    'second_keyword': 'gotta',
#    'third_keyword': 'catch'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'think', 'second_keyword': 'it,', 'third_keyword': 'just'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'think', 'second_keyword': 'it,', 'third_keyword': 'just'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'think', 'second_keyword': 'it,', 'third_keyword': 'just'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'no,',
#    'second_keyword': 'body,',
#    'third_keyword': 'crime'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': "ain't",
#    'second_keyword': "lettin'",
#    'third_keyword': 'day'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'no,', 'second_keyword': 'None', 'third_keyword': 'None'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'think',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'no,', 'second_keyword': 'None', 'third_keyword': 'None'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'None', 'second_keyword': 'None', 'third_keyword': 'None'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'good',
#    'second_keyword': 'thing',
#    'third_keyword': 'daddy'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'cleaned',
#    'second_keyword': 'enough',
#    'third_keyword': 'houses'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'good',
#    'second_keyword': 'thing',
#    'third_keyword': "este's"},
#   '\u200bno body, no crime'),
#  ({'first_keyword': '(she', 'second_keyword': 'me,', 'third_keyword': 'dude)'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'good',
#    'second_keyword': 'thing',
#    'third_keyword': 'mistress'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'think', 'second_keyword': 'it,', 'third_keyword': 'just'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'think', 'second_keyword': 'it,', 'third_keyword': 'just'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'thinks',
#    'second_keyword': 'it,',
#    'third_keyword': 'just'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'no,',
#    'second_keyword': 'body,',
#    'third_keyword': 'crime'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': "lettin'",
#    'second_keyword': 'day',
#    'third_keyword': 'he—'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'no,',
#    'second_keyword': 'body,',
#    'third_keyword': 'crime'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': "lettin'",
#    'second_keyword': 'day',
#    'third_keyword': 'he—'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'no,',
#    'second_keyword': 'body,',
#    'third_keyword': 'crime'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': "lettin'",
#    'second_keyword': 'day',
#    'third_keyword': 'died'},
#   '\u200bno body, no crime'),
#  ({'first_keyword': 'honey,',
#    'second_keyword': 'trees',
#    'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'see', 'second_keyword': 'None', 'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'now', 'second_keyword': 'right', 'third_keyword': 'it,'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'just',
#    'second_keyword': 'shit',
#    'third_keyword': "dividin'"},
#   '\u200bhappiness'),
#  ({'first_keyword': 'showed',
#    'second_keyword': 'hiding',
#    'third_keyword': 'spots'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'dancing',
#    'second_keyword': 'music',
#    'third_keyword': 'stopped'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'disbelief,',
#    'second_keyword': 'face',
#    'third_keyword': 'reinvention'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'met', 'second_keyword': 'new', 'third_keyword': 'yet'},
#   '\u200bhappiness'),
#  ({'first_keyword': "there'll",
#    'second_keyword': 'happiness',
#    'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'happiness',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'things',
#    'second_keyword': 'can',
#    'third_keyword': 'true'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'happiness',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'past',
#    'second_keyword': 'blood',
#    'third_keyword': 'bruise'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'past',
#    'second_keyword': 'curses',
#    'third_keyword': 'cries'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'beyond',
#    'second_keyword': 'terror',
#    'third_keyword': 'nightfall'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'haunted',
#    'second_keyword': 'look',
#    'third_keyword': 'eyes'},
#   '\u200bhappiness'),
#  ({'first_keyword': "would've",
#    'second_keyword': 'loved',
#    'third_keyword': 'lifetime'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'leave',
#    'second_keyword': 'behind',
#    'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'happiness',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'tell',
#    'second_keyword': 'me,',
#    'third_keyword': 'winning'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'begin',
#    'second_keyword': 'look',
#    'third_keyword': 'like'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'lessons',
#    'second_keyword': 'start',
#    'third_keyword': 'look'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'pointed',
#    'second_keyword': 'deepest',
#    'third_keyword': 'hurt?'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'hope',
#    'second_keyword': 'beautiful',
#    'third_keyword': 'fool'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'takes',
#    'second_keyword': 'spot',
#    'third_keyword': 'next'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'no,', 'second_keyword': 'mean', 'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'sorry,',
#    'second_keyword': 'see',
#    'third_keyword': 'facts'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'met', 'second_keyword': 'new', 'third_keyword': 'yet'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'joeboy',
#    'second_keyword': "'sip",
#    'third_keyword': "(alcohol)'"},
#   '\u200bhappiness'),
#  ({'first_keyword': "there'll",
#    'second_keyword': 'happiness',
#    'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'happiness',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'things,',
#    'second_keyword': 'believe',
#    'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'happiness',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'history,',
#    'second_keyword': 'across',
#    'third_keyword': 'great'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'glorious',
#    'second_keyword': 'sunrise',
#    'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'dappled',
#    'second_keyword': 'flickers',
#    'third_keyword': 'light'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'dress',
#    'second_keyword': 'wore',
#    'third_keyword': 'midnight,'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'happiness',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'make', 'second_keyword': 'go', 'third_keyword': 'away'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'guess',
#    'second_keyword': 'price',
#    'third_keyword': 'paid'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'pulled',
#    'second_keyword': 'body',
#    'third_keyword': 'mine'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'every',
#    'second_keyword': 'goddamn',
#    'third_keyword': 'night,'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'one',
#    'second_keyword': 'teaches',
#    'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'good', 'second_keyword': 'man', 'third_keyword': 'hurts'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'know', 'second_keyword': 'hurt', 'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'honey,',
#    'second_keyword': 'trees',
#    'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'see', 'second_keyword': 'None', 'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'now', 'second_keyword': 'eyes', 'third_keyword': 'leak'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'giving',
#    'second_keyword': 'best',
#    'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'tell', 'second_keyword': 'give', 'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'want', 'second_keyword': 'now', 'third_keyword': 'green'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'met', 'second_keyword': 'new', 'third_keyword': 'yet'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'think',
#    'second_keyword': 'give',
#    'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': "there'll",
#    'second_keyword': 'happiness',
#    'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'happiness',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'things',
#    'second_keyword': 'can',
#    'third_keyword': 'true'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'happiness',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'history,',
#    'second_keyword': 'across',
#    'third_keyword': 'great'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'glorious',
#    'second_keyword': 'sunrise',
#    'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'dappled',
#    'second_keyword': 'flickers',
#    'third_keyword': 'light'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'dress',
#    'second_keyword': 'wore',
#    'third_keyword': 'midnight,'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'oh,',
#    'second_keyword': 'leave',
#    'third_keyword': 'behind'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'leave',
#    'second_keyword': 'behind',
#    'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'happiness',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   '\u200bhappiness'),
#  ({'first_keyword': 'hey,',
#    'second_keyword': 'dorothea,',
#    'third_keyword': 'ever'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'younger',
#    'second_keyword': 'park',
#    'third_keyword': 'None'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'honey,',
#    'second_keyword': 'making',
#    'third_keyword': 'lark'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'got',
#    'second_keyword': 'shiny',
#    'third_keyword': 'friends'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'tiny',
#    'second_keyword': "screen's",
#    'third_keyword': 'place'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'got',
#    'second_keyword': 'nothing',
#    'third_keyword': 'well'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'ooh,',
#    'second_keyword': 'place',
#    'third_keyword': 'ever'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'ooh,', 'second_keyword': 'like', 'third_keyword': 'way'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'never',
#    'second_keyword': 'late',
#    'third_keyword': 'come'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'stars',
#    'second_keyword': 'eyes',
#    'third_keyword': 'shined'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'ever',
#    'second_keyword': 'tired',
#    'third_keyword': 'bеing'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'know',
#    'second_keyword': 'always',
#    'third_keyword': 'know'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'dorothea',
#    'second_keyword': '(ah-ah)',
#    'third_keyword': 'None'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'ooh,',
#    'second_keyword': "you'rе",
#    'third_keyword': 'queen'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'ooh,', 'second_keyword': 'you,', 'third_keyword': 'buy'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'hey,',
#    'second_keyword': 'dorothea,',
#    'third_keyword': 'ever'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'calmer,',
#    'second_keyword': 'skipping',
#    'third_keyword': 'prom'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'damn,',
#    'second_keyword': 'dorothea,',
#    'third_keyword': 'wanna'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'still', 'second_keyword': 'soul', 'third_keyword': 'met'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'ooh,',
#    'second_keyword': 'guess',
#    'third_keyword': 'never'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'ooh,', 'second_keyword': 'go', 'third_keyword': 'show'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'never',
#    'second_keyword': 'late',
#    'third_keyword': 'come'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'stars',
#    'second_keyword': 'eyes',
#    'third_keyword': 'shined'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'ever',
#    'second_keyword': 'tired',
#    'third_keyword': 'known'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'know,',
#    'second_keyword': 'always',
#    'third_keyword': 'know'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'dorothea',
#    'second_keyword': '(ah-ah)',
#    'third_keyword': 'None'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'ooh,', 'second_keyword': 'ooh', 'third_keyword': 'None'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'ooh-woo-ooh-ooh-ooh,',
#    'second_keyword': 'ooh-ooh-ooh-ooh',
#    'third_keyword': 'None'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'ooh,', 'second_keyword': 'ooh', 'third_keyword': 'None'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'ooh-woo-ooh-ooh-ooh,',
#    'second_keyword': 'ooh-ooh-ooh',
#    'third_keyword': 'None'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'dorothea',
#    'second_keyword': '(ah-ah-ah)',
#    'third_keyword': 'None'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'ah-ah',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'ooh', 'second_keyword': 'None', 'third_keyword': 'None'},
#   '\u200bdorothea'),
#  ({'first_keyword': 'break', 'second_keyword': 'soul', 'third_keyword': 'two'},
#   '\u200bconey island'),
#  ({'first_keyword': 'right',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   '\u200bconey island'),
#  ({'first_keyword': 'relate',
#    'second_keyword': 'anymore',
#    'third_keyword': 'None'},
#   '\u200bconey island'),
#  ({'first_keyword': 'related',
#    'second_keyword': 'to?',
#    'third_keyword': 'None'},
#   '\u200bconey island'),
#  ({'first_keyword': 'long', 'second_keyword': 'haul', 'third_keyword': 'None'},
#   '\u200bconey island'),
#  ({'first_keyword': "how'd",
#    'second_keyword': 'get',
#    'third_keyword': 'soon?'},
#   '\u200bconey island'),
#  ({'first_keyword': 'close',
#    'second_keyword': 'fist',
#    'third_keyword': 'around'},
#   '\u200bconey island'),
#  ({'first_keyword': 'shatter',
#    'second_keyword': 'you?',
#    'third_keyword': 'None'},
#   '\u200bconey island'),
#  ({'first_keyword': 'sitting',
#    'second_keyword': 'bench',
#    'third_keyword': 'coney'},
#   '\u200bconey island'),
#  ({'first_keyword': 'wondering',
#    'second_keyword': 'baby',
#    'third_keyword': 'go?'},
#   '\u200bconey island'),
#  ({'first_keyword': 'fast',
#    'second_keyword': 'times,',
#    'third_keyword': 'bright'},
#   '\u200bconey island'),
#  ({'first_keyword': 'sorry',
#    'second_keyword': 'making',
#    'third_keyword': 'centerfold'},
#   '\u200bconey island'),
#  ({'first_keyword': 'None', 'second_keyword': 'None', 'third_keyword': 'None'},
#   '\u200bconey island'),
#  ({'first_keyword': 'lost',
#    'second_keyword': 'surprises',
#    'third_keyword': 'None'},
#   '\u200bconey island'),
#  ({'first_keyword': 'disappointments,',
#    'second_keyword': 'close',
#    'third_keyword': 'eyes'},
#   '\u200bconey island'),
#  ({'first_keyword': 'gets',
#    'second_keyword': 'colder',
#    'third_keyword': 'colder'},
#   '\u200bconey island'),
#  ({'first_keyword': 'sun', 'second_keyword': 'goes', 'third_keyword': 'None'},
#   '\u200bconey island'),
#  ({'first_keyword': 'question',
#    'second_keyword': 'pounds',
#    'third_keyword': 'head'},
#   '\u200bconey island'),
#  ({'first_keyword': 'lifetime',
#    'second_keyword': 'achievement',
#    'third_keyword': 'None'},
#   '\u200bconey island'),
#  ({'first_keyword': 'pushed',
#    'second_keyword': 'edge?',
#    'third_keyword': 'None'},
#   '\u200bconey island'),
#  ({'first_keyword': 'polite',
#    'second_keyword': 'leave',
#    'third_keyword': 'None'},
#   '\u200bconey island'),
#  ({'first_keyword': 'miss',
#    'second_keyword': 'rogue',
#    'third_keyword': 'None'},
#   '\u200bconey island'),
#  ({'first_keyword': 'coaxed',
#    'second_keyword': 'paradise',
#    'third_keyword': 'left'},
#   '\u200bconey island'),
#  ({'first_keyword': 'will',
#    'second_keyword': 'forgive',
#    'third_keyword': 'soul'},
#   '\u200bconey island'),
#  ({'first_keyword': 'wise', 'second_keyword': 'trust', 'third_keyword': 'old'},
#   '\u200bconey island'),
#  ({'first_keyword': "'cause",
#    'second_keyword': 'like',
#    'third_keyword': 'mall'},
#   '\u200bconey island'),
#  ({'first_keyword': 'one', 'second_keyword': 'place', 'third_keyword': 'None'},
#   '\u200bconey island'),
#  ({'first_keyword': 'mischief,',
#    'second_keyword': 'gift-wrapped',
#    'third_keyword': 'suburban'},
#   '\u200bconey island'),
#  ({'first_keyword': 'sorry',
#    'second_keyword': 'winning',
#    'third_keyword': 'arcade'},
#   '\u200bconey island'),
#  ({'first_keyword': 'None', 'second_keyword': 'None', 'third_keyword': 'None'},
#   '\u200bconey island'),
#  ({'first_keyword': 'lost',
#    'second_keyword': 'surprises',
#    'third_keyword': 'None'},
#   '\u200bconey island'),
#  ({'first_keyword': 'disappointments,',
#    'second_keyword': 'close',
#    'third_keyword': 'eyes'},
#   '\u200bconey island'),
#  ({'first_keyword': 'gets',
#    'second_keyword': 'colder',
#    'third_keyword': 'colder'},
#   '\u200bconey island'),
#  ({'first_keyword': 'sun', 'second_keyword': 'goes', 'third_keyword': 'None'},
#   '\u200bconey island'),
#  ({'first_keyword': 'waiting',
#    'second_keyword': 'old',
#    'third_keyword': 'spot'},
#   '\u200bconey island'),
#  ({'first_keyword': 'tree', 'second_keyword': 'line', 'third_keyword': 'None'},
#   '\u200bconey island'),
#  ({'first_keyword': 'gold',
#    'second_keyword': 'clock',
#    'third_keyword': 'None'},
#   '\u200bconey island'),
#  ({'first_keyword': 'leave',
#    'second_keyword': 'hanging',
#    'third_keyword': 'every'},
#   '\u200bconey island'),
#  ({'first_keyword': 'standing',
# ...
#    'second_keyword': '(to',
#    'third_keyword': 'certain'},
#   '\u200bevermore'),
#  ({'first_keyword': 'real',
#    'second_keyword': 'enough',
#    'third_keyword': '(whether'},
#   '\u200bevermore'),
#  ({'first_keyword': 'get',
#    'second_keyword': '(or',
#    'third_keyword': 'violence'},
#   '\u200bevermore'),
#  ({'first_keyword': '(or',
#    'second_keyword': 'violence',
#    'third_keyword': 'dog'},
#   '\u200bevermore'),
#  ({'first_keyword': '(out',
#    'second_keyword': 'waves,',
#    'third_keyword': 'tossed)'},
#   '\u200bevermore'),
#  ({'first_keyword': "(i'm",
#    'second_keyword': 'waves,',
#    'third_keyword': 'tossed)'},
#   '\u200bevermore'),
#  ({'first_keyword': 'swear', 'second_keyword': '(is', 'third_keyword': 'line'},
#   '\u200bevermore'),
#  ({'first_keyword': 'None', 'second_keyword': 'None', 'third_keyword': 'None'},
#   '\u200bevermore'),
#  ({'first_keyword': 'catching',
#    'second_keyword': 'breath',
#    'third_keyword': 'None'},
#   '\u200bevermore'),
#  ({'first_keyword': 'floors',
#    'second_keyword': 'cabin',
#    'third_keyword': 'creaking'},
#   '\u200bevermore'),
#  ({'first_keyword': 'sure', 'second_keyword': 'None', 'third_keyword': 'None'},
#   '\u200bevermore'),
#  ({'first_keyword': 'feeling',
#    'second_keyword': 'peculiar',
#    'third_keyword': 'None'},
#   '\u200bevermore'),
#  ({'first_keyword': 'pain', 'second_keyword': 'None', 'third_keyword': 'None'},
#   '\u200bevermore'),
#  ({'first_keyword': 'evermore',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   '\u200bevermore'),
#  ({'first_keyword': 'evermore',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   '\u200bevermore'),
#  ({'first_keyword': 'evermore',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   '\u200bevermore'),
#  ({'first_keyword': 'pain',
#    'second_keyword': 'evermore',
#    'third_keyword': 'None'},
#   '\u200bevermore'),
#  ({'first_keyword': 'evermore',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   '\u200bevermore'),
#  ({'first_keyword': 'friends',
#    'second_keyword': 'break',
#    'third_keyword': 'up,'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'strangers',
#    'second_keyword': 'get',
#    'third_keyword': 'born,'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'trends',
#    'second_keyword': 'change,',
#    'third_keyword': 'rumors'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'right',
#    'second_keyword': 'left',
#    'third_keyword': 'None'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'matches',
#    'second_keyword': 'burn',
#    'third_keyword': 'None'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'pages',
#    'second_keyword': 'turn',
#    'third_keyword': 'stick'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'wages',
#    'second_keyword': 'earned',
#    'third_keyword': 'lessons'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'i,', 'second_keyword': 'right', 'third_keyword': 'left'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'help,',
#    'second_keyword': 'still',
#    'third_keyword': 'restaurant'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'still',
#    'second_keyword': 'sitting',
#    'third_keyword': 'corner'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'cross-legged',
#    'second_keyword': 'dim',
#    'third_keyword': 'light'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'say,', 'second_keyword': '"what', 'third_keyword': 'sad'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'i,', 'second_keyword': 'swear', 'third_keyword': 'hear'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'right',
#    'second_keyword': 'felt',
#    'third_keyword': 'moment'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'glass',
#    'second_keyword': 'shattered',
#    'third_keyword': 'white'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'everybody',
#    'second_keyword': 'moved',
#    'third_keyword': 'on,'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'dust',
#    'second_keyword': 'collected',
#    'third_keyword': 'pinned-up'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'expected',
#    'second_keyword': 'find',
#    'third_keyword': 'somewhere'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'perspective,',
#    'second_keyword': 'sat',
#    'third_keyword': 'stared'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'right',
#    'second_keyword': 'left',
#    'third_keyword': 'None'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'left', 'second_keyword': 'no,', 'third_keyword': 'left'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'left',
#    'second_keyword': 'choice',
#    'third_keyword': 'stay'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'left', 'second_keyword': 'me,', 'third_keyword': 'left'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'left',
#    'second_keyword': 'choice',
#    'third_keyword': 'stay'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'joeboy',
#    'second_keyword': "'sip",
#    'third_keyword': "(alcohol)'"},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'ever', 'second_keyword': 'hear', 'third_keyword': 'girl'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'time',
#    'second_keyword': 'went',
#    'third_keyword': 'everybody'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'still',
#    'second_keyword': 'twenty-three',
#    'third_keyword': 'inside'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'supposed',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'hear',
#    'second_keyword': 'girl',
#    'third_keyword': 'lives'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'breakups',
#    'second_keyword': 'happen',
#    'third_keyword': 'every'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'still',
#    'second_keyword': 'twenty-three',
#    'third_keyword': 'inside'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'sitting',
#    'second_keyword': 'front',
#    'third_keyword': 'None'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'restaurant',
#    'second_keyword': 'still',
#    'third_keyword': 'one'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'cross-legged',
#    'second_keyword': 'dim',
#    'third_keyword': 'light,'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'i,',
#    'second_keyword': 'feel',
#    'third_keyword': 'mascara'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'told',
#    'second_keyword': 'met',
#    'third_keyword': 'someone'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'glass',
#    'second_keyword': 'shattered',
#    'third_keyword': 'white'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'everybody',
#    'second_keyword': 'moved',
#    'third_keyword': 'None'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'help,',
#    'second_keyword': 'still',
#    'third_keyword': 'restaurant'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'still',
#    'second_keyword': 'sitting',
#    'third_keyword': 'corner'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'cross-legged',
#    'second_keyword': 'dim',
#    'third_keyword': 'light'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'say,', 'second_keyword': '"what', 'third_keyword': 'sad'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'i,', 'second_keyword': 'stayed', 'third_keyword': 'None'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'dust',
#    'second_keyword': 'collected',
#    'third_keyword': 'pinned-up'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'sure', 'second_keyword': 'got', 'third_keyword': 'wife'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'kids',
#    'second_keyword': 'christmas,',
#    'third_keyword': 'unaware'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': "'cause",
#    'second_keyword': 'right',
#    'third_keyword': 'cause'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'mind',
#    'second_keyword': 'business',
#    'third_keyword': 'None'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'love',
#    'second_keyword': 'died',
#    'third_keyword': 'young'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'bear',
#    'second_keyword': 'witness',
#    'third_keyword': 'None'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'long', 'second_keyword': 'None', 'third_keyword': 'None'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'ever', 'second_keyword': 'think', 'third_keyword': 'got'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'right',
#    'second_keyword': 'None',
#    'third_keyword': 'None'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'left', 'second_keyword': 'None', 'third_keyword': 'None'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'left', 'second_keyword': 'no,', 'third_keyword': 'oh,'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'left',
#    'second_keyword': 'choice',
#    'third_keyword': 'stay'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'left', 'second_keyword': 'None', 'third_keyword': 'None'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'left', 'second_keyword': 'no,', 'third_keyword': 'oh,'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'left',
#    'second_keyword': 'choice',
#    'third_keyword': 'stay'},
#   '\u200br\u200bight where you left me'),
#  ({'first_keyword': 'dinner',
#    'second_keyword': 'cold',
#    'third_keyword': 'chatter'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'ask', 'second_keyword': 'tab', 'third_keyword': 'None'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'moment',
#    'second_keyword': 'again,',
#    'third_keyword': 'insisting'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'look', 'second_keyword': 'like', 'third_keyword': 'None'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'words',
#    'second_keyword': 'sister',
#    'third_keyword': 'come'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'prove',
#    'second_keyword': 'fact',
#    'third_keyword': 'seemed'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'twin',
#    'second_keyword': 'dreams',
#    'third_keyword': 'None'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'crook',
#    'second_keyword': 'caught',
#    'third_keyword': 'None'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'old',
#    'second_keyword': 'familiar',
#    'third_keyword': 'body'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'snaps',
#    'second_keyword': 'little',
#    'third_keyword': 'breaks'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'know', 'second_keyword': 'time', 'third_keyword': 'go'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'twenty',
#    'second_keyword': 'years',
#    'third_keyword': 'job'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'son', 'second_keyword': 'boss', 'third_keyword': 'gets'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'trying',
#    'second_keyword': 'stay',
#    'third_keyword': 'kids'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'keeping',
#    'second_keyword': 'will',
#    'third_keyword': 'break'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'old',
#    'second_keyword': 'familiar',
#    'third_keyword': 'body'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'snaps',
#    'second_keyword': 'little',
#    'third_keyword': 'breaks'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'know', 'second_keyword': 'time', 'third_keyword': 'go'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'sometimes',
#    'second_keyword': 'giving',
#    'third_keyword': 'strong'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'sometimes',
#    'second_keyword': 'run',
#    'third_keyword': 'brave'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'sometimes',
#    'second_keyword': 'walking',
#    'third_keyword': 'one'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'will',
#    'second_keyword': 'find',
#    'third_keyword': 'right'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'sometimes',
#    'second_keyword': 'giving',
#    'third_keyword': 'strong'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'sometimes',
#    'second_keyword': 'run',
#    'third_keyword': 'brave'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'sometimes',
#    'second_keyword': 'walking',
#    'third_keyword': 'one'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'will',
#    'second_keyword': 'find',
#    'third_keyword': 'right'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'fifteen',
#    'second_keyword': 'years,',
#    'third_keyword': 'fifteen'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'begging',
#    'second_keyword': "'til",
#    'third_keyword': 'knees'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'gave', 'second_keyword': 'all,', 'third_keyword': 'gave'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'wondered',
#    'second_keyword': 'left',
#    'third_keyword': 'None'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'now',
#    'second_keyword': 'sits',
#    'third_keyword': 'throne'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'praying',
#    'second_keyword': 'greed',
#    'third_keyword': 'None'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'got',
#    'second_keyword': 'past',
#    'third_keyword': 'frozen'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'got', 'second_keyword': 'None', 'third_keyword': 'None'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'old',
#    'second_keyword': 'familiar',
#    'third_keyword': 'body'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'snaps',
#    'second_keyword': 'little',
#    'third_keyword': 'breaks'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'know', 'second_keyword': 'time', 'third_keyword': 'go'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'sometimes',
#    'second_keyword': 'giving',
#    'third_keyword': 'strong'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'sometimes',
#    'second_keyword': 'run',
#    'third_keyword': 'brave'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'sometimes',
#    'second_keyword': 'walking',
#    'third_keyword': 'one'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'will',
#    'second_keyword': 'find',
#    'third_keyword': 'right'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'sometimes',
#    'second_keyword': 'giving',
#    'third_keyword': 'strong'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'sometimes',
#    'second_keyword': 'run',
#    'third_keyword': 'brave'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'sometimes',
#    'second_keyword': 'walking',
#    'third_keyword': 'one'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'will',
#    'second_keyword': 'find',
#    'third_keyword': 'right'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'will',
#    'second_keyword': 'find',
#    'third_keyword': 'right'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'know', 'second_keyword': 'soul', 'third_keyword': 'None'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'know', 'second_keyword': 'soul', 'third_keyword': 'None'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'time', 'second_keyword': 'go', 'third_keyword': 'None'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'know,',
#    'second_keyword': 'know,',
#    'third_keyword': 'know,'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'time', 'second_keyword': 'go', 'third_keyword': 'None'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'go', 'second_keyword': 'None', 'third_keyword': 'None'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'go', 'second_keyword': 'None', 'third_keyword': 'None'},
#   '\u200bit’s time to go'),
#  ({'first_keyword': 'just', 'second_keyword': 'go', 'third_keyword': 'None'},
#   '\u200bit’s time to go')]

# %%
# always shuffle your featureset before classifying!
import random
random.shuffle(feature_sets)

# %%
import math

split_num = math.floor(len(feature_sets) * .8)

# 80% of my data
training_set = feature_sets[:split_num]
# 20% of my data
testing_set = feature_sets[split_num:]

# %%
import nltk
# create our classifier
classifier = nltk.NaiveBayesClassifier.train(training_set)

# %%
# try out our classifier using a headline
classifier.classify(create_features("Lost in your current like a priceless wine"))
# Out:
# '\u200bconey island'

# %%
# determine the accuracy of our classifier
print(nltk.classify.accuracy(classifier, testing_set))
# Out:
# 0.4972677595628415

# %%
# show the most important features for our algorithm
classifier.show_most_informative_features(12)
# Out:
# Most Informative Features
#           second_keyword = 'None'         ​everm : ​marjo =      8.3 : 1.0
#            first_keyword = 'no,'          ​no bo : ​happi =      7.9 : 1.0
#           second_keyword = 'stay'         ​marjo : ​it’s  =      6.9 : 1.0
#            first_keyword = 'left'         ​r​igh : ​marjo =      6.3 : 1.0
#            first_keyword = 'think'        ​no bo : ​happi =      5.9 : 1.0
#            first_keyword = 'like'         ​gold  : ​l​ong =      5.6 : 1.0
#            first_keyword = 'know'         ​marjo : ​happi =      5.1 : 1.0
#            third_keyword = 'None'         ​l​ong : willow =      4.9 : 1.0
#            first_keyword = 'long'         ​l​ong : ​r​igh =      4.7 : 1.0
#            first_keyword = 'everybody'    ​gold  : ​r​igh =      4.6 : 1.0
#            first_keyword = 'begging'      willow : ​it’s  =      4.4 : 1.0
#           second_keyword = 'like'         ​gold  : ​l​ong =      4.1 : 1.0
